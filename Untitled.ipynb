# %%
import pandas as pd

# %%
data = pd.read_csv('BankChurners.csv')
data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
data = pd.read_csv('superstore_train.csv')
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
import pandas as pd

# %%
data = pd.read_csv('Credit_Score_Classification.csv')
data.head(20)
# Out:
# C:\Users\SILAS\AppData\Local\Temp\ipykernel_11072\2970041858.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('Credit_Score_Classification.csv')
#         ID Customer_ID     Month             Name   Age          SSN  \
# 0   0x1602   CUS_0xd40   January    Aaron Maashoh    23  821-00-0265
# 1   0x1603   CUS_0xd40  February    Aaron Maashoh    23  821-00-0265
# 2   0x1604   CUS_0xd40     March    Aaron Maashoh  -500  821-00-0265
# 3   0x1605   CUS_0xd40     April    Aaron Maashoh    23  821-00-0265
# 4   0x1606   CUS_0xd40       May    Aaron Maashoh    23  821-00-0265
# 5   0x1607   CUS_0xd40      June    Aaron Maashoh    23  821-00-0265
# 6   0x1608   CUS_0xd40      July    Aaron Maashoh    23  821-00-0265
# 7   0x1609   CUS_0xd40    August              NaN    23    #F%$D@*&8
# 8   0x160e  CUS_0x21b1   January  Rick Rothackerj   28_  004-07-5839
# ...

# %%
categorical = data.select_dtypes(include = ['object', 'category'])
numerical = data.select_dtypes(include = 'number')

print(f"Categorical ds")
display(categorical.head(2))

print(f"\n\nNumerical ds")
display(numerical.head(2))
# Out:
# Categorical ds
#        ID Customer_ID     Month           Name Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh  23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh  23  821-00-0265  Scientist
#
#   Annual_Income Num_of_Loan  \
# 0      19114.12           4
# 1      19114.12           4
#
#                                         Type_of_Loan Num_of_Delayed_Payment  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...                      7
# 1  Auto Loan, Credit-Builder Loan, Personal Loan,...                    NaN
#
#   Changed_Credit_Limit Credit_Mix Outstanding_Debt     Credit_History_Age  \
# 0                11.27          _           809.98  22 Years and 1 Months
# 1                11.27       Good           809.98                    NaN
#
#   Payment_of_Min_Amount Amount_invested_monthly  \
# 0                    No       80.41529543900253
# 1                    No      118.28022162236736
#
# ...

# %%
data.Monthly_Balance.sample(200).values
# Out:
# array(['218.65443949201932', '108.58999080430401', '660.6827075896521',
#        '402.1803639698511', '765.0059224620303', '499.56436906134473',
#        '372.706954875054', '958.0305243471463', '316.333168465374',
#        '426.85554341631035', '356.969672618952', '288.6410378892549',
#        '430.5858463071549', '239.07324325771657', '226.44650181272812',
#        '434.7944208343284', '1113.5521039299251', '255.12403684464093',
#        '785.316628304352', '277.3730325857198', '412.74640487126226',
#        '279.06540187846736', '271.745838705882', '286.53393511156725',
#        '624.017273146856', '615.3847656379935', '328.5289001491927',
#        '567.8289931378654', '287.2714045921622', '341.62003355306274',
#        '479.7782503477284', '255.39281000754747', 382.0007806418877,
#        '433.65799935607237', '286.8942807925888', '208.25346251321355',
#        265.2305609118137, '345.70921831837904', '479.88611512672793',
# ...

# %%
data['Age'].sample(200).values
data.Age = data['Age'].str.replace('_', '')
data.Age = data['Age'].str.replace('-', '')
data.Age = data.Age.astype(float)
data.Age.dtypes
# Out:
# dtype('float64')

# %%
data['Annual_Income'].sample(200).values
data.Annual_Income = data['Annual_Income'].str.replace('_', '')
data.Annual_Income = data['Annual_Income'].str.replace('-', '')
data.Annual_Income = data.Annual_Income.astype(float)
data.Annual_Income.dtypes
# Out:
# dtype('float64')

# %%
data['Num_of_Loan'].sample(200).values
data.Num_of_Loan = data['Num_of_Loan'].str.replace('_', '')
data.Num_of_Loan = data['Num_of_Loan'].str.replace('-', '')
data.Num_of_Loan = data.Num_of_Loan.astype(float)
data.Num_of_Loan.dtypes
# Out:
# dtype('float64')

# %%
data['Num_of_Delayed_Payment'].sample(200).values
data.Num_of_Delayed_Payment = data['Num_of_Delayed_Payment'].str.replace('_', '')
data.Num_of_Delayed_Payment = data['Num_of_Delayed_Payment'].str.replace('-', '')
data.Num_of_Delayed_Payment = data.Num_of_Delayed_Payment.astype(float)
data.Num_of_Delayed_Payment.dtypes
# Out:
# dtype('float64')

# %%
data['Outstanding_Debt'].sample(200).values
data.Outstanding_Debt = data['Outstanding_Debt'].str.replace('_', '')
data.Outstanding_Debt = data['Outstanding_Debt'].str.replace('-', '')
data.Outstanding_Debt = data.Outstanding_Debt.astype(float)
data.Outstanding_Debt.dtypes
# Out:
# dtype('float64')

# %%
data['Amount_invested_monthly'].sample(200).values
data.Amount_invested_monthly = data['Amount_invested_monthly'].str.replace('_', '')
data.Amount_invested_monthly = data['Amount_invested_monthly'].str.replace('-', '')
data.Amount_invested_monthly = data.Amount_invested_monthly.astype(float)
data.Amount_invested_monthly.dtypes
# Out:
# dtype('float64')

# %%
data['Changed_Credit_Limit'].sample(200).values
data.Changed_Credit_Limit = data['Changed_Credit_Limit'].str.replace('_', '')
data.Changed_Credit_Limit = data['Changed_Credit_Limit'].str.replace('-', '')
data.Changed_Credit_Limit = pd.to_numeric(data.Changed_Credit_Limit, errors = 'coerce')
data.Changed_Credit_Limit.dtypes
# Out:
# dtype('float64')

# %%
data['Monthly_Balance'].sample(200).values
data.Monthly_Balance = data['Monthly_Balance'].str.replace('_', '')
data.Monthly_Balance = data.Monthly_Balance.astype(float)
data.Monthly_Balance.dtypes
# Out:
# dtype('float64')

# %%
for i in data.columns:
    if ((data[i].isnull().sum()/ len(data)) * 100) > 30:
        data.drop([i], axis = 1, inplace = True)

    elif data[i].dtypes == 'O':
        data[i].fillna(data[i].mode()[0], inplace = True)

    else:
        data[i].fillna(data[i].median(), inplace = True)

data.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
data.describe()
# Out:
#                  Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  100000.000000   1.000000e+05          100000.000000      100000.000000
# mean      119.509700   1.764157e+05            4029.084964          17.091280
# std       684.757313   1.429618e+06            2961.363540         117.404834
# min        14.000000   7.005930e+03             303.645417          -1.000000
# 25%        25.000000   1.945750e+04            1792.084167           3.000000
# 50%        34.000000   3.757861e+04            3093.745000           6.000000
# 75%        42.000000   7.279092e+04            5371.525000           7.000000
# max      8698.000000   2.419806e+07           15204.633333        1798.000000
#
#        Num_Credit_Card  Interest_Rate    Num_of_Loan  Delay_from_due_date  \
# count     100000.00000  100000.000000  100000.000000        100000.000000
# mean          22.47443      72.466040      10.761960            21.068780
# ...

# %%
minThreshold = data.Age.describe()[4] - 1.5 * (data.Age.describe()[6] - data.Age.describe()[4])
maxThreshold = data.Age.describe()[6] + 1.5 * (data.Age.describe()[6] - data.Age.describe()[4])


print(f"Minimum Threshold = {minThreshold}\nMaximum Threshold = {maxThreshold}")
# Out:
# Minimum Threshold = -0.5
# Maximum Threshold = 67.5

# %%
def outlierRemoval(dataframe):
    for i in dataframe.columns:
        if dataframe[i].dtypes != 'O': # --------------------------------------- If the data type is not an object type
            Q1 = dataframe[i].describe()[4] # ---------------------------------- Identify lower Quartile
            Q3 = dataframe[i].describe()[6] # ---------------------------------- Identify the upper quartile
            IQR = Q3 - Q1 # ---------------------------------------------------- Get Inter Quartile Range
            minThreshold = Q1 - 1.5 * IQR # ------------------------------------ Get Minimum Threshold
            maxThreshold = Q3 + 1.5 * IQR # ------------------------------------ Get Maximum Threshold

            dataframe = dataframe.loc[(dataframe[i] >= minThreshold) & (dataframe[i] <= maxThreshold)]
    return dataframe

data = outlierRemoval(data)
data.head(20)
# Out:
#         ID Customer_ID     Month             Name   Age          SSN  \
# 0   0x1602   CUS_0xd40   January    Aaron Maashoh  23.0  821-00-0265
# 1   0x1603   CUS_0xd40  February    Aaron Maashoh  23.0  821-00-0265
# 3   0x1605   CUS_0xd40     April    Aaron Maashoh  23.0  821-00-0265
# 4   0x1606   CUS_0xd40       May    Aaron Maashoh  23.0  821-00-0265
# 5   0x1607   CUS_0xd40      June    Aaron Maashoh  23.0  821-00-0265
# 6   0x1608   CUS_0xd40      July    Aaron Maashoh  23.0  821-00-0265
# 7   0x1609   CUS_0xd40    August           Langep  23.0    #F%$D@*&8
# 8   0x160e  CUS_0x21b1   January  Rick Rothackerj  28.0  004-07-5839
# 9   0x160f  CUS_0x21b1  February  Rick Rothackerj  28.0  004-07-5839
# 11  0x1611  CUS_0x21b1     April  Rick Rothackerj  28.0  004-07-5839
# 12  0x1612  CUS_0x21b1       May  Rick Rothackerj  28.0  004-07-5839
# 13  0x1613  CUS_0x21b1      June  Rick Rothackerj  28.0  004-07-5839
# 14  0x1614  CUS_0x21b1      July  Rick Rothackerj  28.0  004-07-5839
# ...

# %%
# Data Insights
# - What is the occupation of the customer name with the highest Annual Income
# - what month makes the most annual income
# - What Occupation has the most annual income
# - what occupation has the highest number of credit card
# - What occupation has the least changed credit limit
# - What occupation has the most outstanding debt

# %%
# - What is the occupation of the customer name with the highest Annual Income
needed = data[['Occupation', 'Annual_Income', 'Name']]
needed.groupby(['Name','Occupation'])[['Annual_Income']].sum(). sort_values (by = 'Annual_Income', ascending = False)
# Out:
#                             Annual_Income
# Name          Occupation
# Langep        _______        1.524574e+07
#               Lawyer         1.445763e+07
#               Entrepreneur   1.445678e+07
#               Architect      1.372676e+07
#               Mechanic       1.310512e+07
# ...                                   ...
# Joshuaw       _______        7.136905e+03
# Ering         _______        7.056405e+03
# Martonc       _______        7.023160e+03
# Ronaldh       _______        7.020545e+03
# Scott Maloneu _______        7.019435e+03
#
# [12732 rows x 1 columns]

# %%
# - what month makes the most annual income
needed = data[['Month', 'Annual_Income']]
needed.groupby('Month')[['Annual_Income']].sum(). sort_values (by = 'Annual_Income', ascending = False)
# Out:
#           Annual_Income
# Month
# February   2.634499e+08
# January    2.604604e+08
# March      2.588866e+08
# April      2.564357e+08
# June       2.558219e+08
# May        2.553212e+08
# July       2.538843e+08
# August     2.504300e+08

# %%
import numpy as np

name = ['Danny','Sammy', 'Uju',np.NaN,'Mike']
age = [12, 45,np.NaN, 32, 34]
id = ['apol1', 'we344', '7gd6', 'sd212','gh789']

dataframe = pd.DataFrame({'id':id,'name': name, 'age': age})
dataframe
# Out:
#       id   name   age
# 0  apol1  Danny  12.0
# 1  we344  Sammy  45.0
# 2   7gd6    Uju   NaN
# 3  sd212    NaN  32.0
# 4  gh789   Mike  34.0

# %%
import pandas as pd

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56135 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        56135 non-null  object
#  1   Customer_ID               56135 non-null  object
#  2   Month                     56135 non-null  object
#  3   Name                      56135 non-null  object
#  4   Age                       56135 non-null  float64
#  5   SSN                       56135 non-null  object
#  6   Occupation                56135 non-null  object
#  7   Annual_Income             56135 non-null  float64
#  8   Monthly_Inhand_Salary     56135 non-null  float64
#  9   Num_Bank_Accounts         56135 non-null  int64
#  10  Num_Credit_Card           56135 non-null  int64
#  11  Interest_Rate             56135 non-null  int64
#  12  Num_of_Loan               56135 non-null  float64
# ...
